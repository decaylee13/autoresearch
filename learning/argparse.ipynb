# %%
import argparse

#Step 1: Create an argpaser 
parser = argparse.ArgumentParser(description="testing argparser")
#Step 2: Add arguments 
parser.add_argument("--firstname", type=str, required=True)
parser.add_argument("--lastname", type=str)
#Step 3: pass in all of the arguments
args = parser.parse_args()

print(args.firstname)
print(args.lastname)
# Out:
# /Users/dklee/Library/Jupyter/runtime/kernel-v3f44f6cdabef997a07d6a07cfdd07079b5d29a3b4.json
# None
